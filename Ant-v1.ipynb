# %%
import tensorflow as tf
from Strategy import RL

case_num = 1

# 1 : epsilon , 2 : softmax , 3 : sparsemax
Exp_list = ['epsilon', 'softmax', 'sparsemax']

action_res_list = [3, 3, 3, 3, 3, 3, 3, 3]

config = tf.ConfigProto()
config.gpu_options.allow_growth = True

for i in range(case_num):
    tf.reset_default_graph()
    
    with tf.Session(config=config) as sess :
        
        CartPole = RL(sess, max_steps = 1500000, size_action_batch = 64, beta_max_step = 400000,
                      
                      batch_size = 256, training_step = 1, copy_step = 1,
                      action_copy_step = 100, eps_div = 400, s_scale = 0.01,
                      layer_size_Q1 = 400, layer_size_Q2 = 300, learning_rate_Q = 0.0001, learning_rate_A = 0.01,
                      
                      action_res = action_res_list,
                      random_action = True, action_train = True, weighted_train = True, DDPG = False,
                      ending_cond_reward = 10000, save_epi = 100,
                      
                      Game = 'Ant-v1', Exp = 'sparsemax', seed_n = i+1, Prioritized = True,
                      file_name = 'Ant(J)_RA_SP(64)_(256,1,1,100,400,0.01,0.0001,0.01)_CASE3') #0.4, 10.
    
    sess.close()
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# [2018-05-10 22:23:40,944] Making new env: Ant-v1
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/util/tf_should_use.py:107: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# [2018-05-10 22:23:42,369] From /usr/local/lib/python2.7/dist-packages/tensorflow/python/util/tf_should_use.py:107: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# CASE 2
# ...
